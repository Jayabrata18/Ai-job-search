# %%
# %pip install python-dotenv  pandas -U python-jobspy groq
# Out:
# Requirement already satisfied: python-dotenv in /opt/anaconda3/lib/python3.12/site-packages (1.0.1)
# Requirement already satisfied: pandas in /opt/anaconda3/lib/python3.12/site-packages (2.2.3)
# Requirement already satisfied: python-jobspy in /opt/anaconda3/lib/python3.12/site-packages (1.1.75)
# Collecting python-jobspy
#   Using cached python_jobspy-1.1.76-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: groq in /opt/anaconda3/lib/python3.12/site-packages (0.13.0)
# Requirement already satisfied: numpy>=1.26.0 in /opt/anaconda3/lib/python3.12/site-packages (from pandas) (1.26.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/anaconda3/lib/python3.12/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/lib/python3.12/site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/anaconda3/lib/python3.12/site-packages (from pandas) (2023.3)
# Requirement already satisfied: beautifulsoup4<5.0.0,>=4.12.2 in /opt/anaconda3/lib/python3.12/site-packages (from python-jobspy) (4.12.3)
# Requirement already satisfied: markdownify<0.14.0,>=0.13.1 in /opt/anaconda3/lib/python3.12/site-packages (from python-jobspy) (0.13.1)
# Requirement already satisfied: pydantic<3.0.0,>=2.3.0 in /opt/anaconda3/lib/python3.12/site-packages (from python-jobspy) (2.9.2)
# Requirement already satisfied: regex<2025.0.0,>=2024.4.28 in /opt/anaconda3/lib/python3.12/site-packages (from python-jobspy) (2024.11.6)
# Requirement already satisfied: requests<3.0.0,>=2.31.0 in /opt/anaconda3/lib/python3.12/site-packages (from python-jobspy) (2.32.2)
# Requirement already satisfied: tls-client<2.0.0,>=1.0.1 in /opt/anaconda3/lib/python3.12/site-packages (from python-jobspy) (1.0.1)
# Requirement already satisfied: anyio<5,>=3.5.0 in /opt/anaconda3/lib/python3.12/site-packages (from groq) (4.2.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /opt/anaconda3/lib/python3.12/site-packages (from groq) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /opt/anaconda3/lib/python3.12/site-packages (from groq) (0.27.0)
# Requirement already satisfied: sniffio in /opt/anaconda3/lib/python3.12/site-packages (from groq) (1.3.0)
# Requirement already satisfied: typing-extensions<5,>=4.7 in /opt/anaconda3/lib/python3.12/site-packages (from groq) (4.11.0)
# Requirement already satisfied: idna>=2.8 in /opt/anaconda3/lib/python3.12/site-packages (from anyio<5,>=3.5.0->groq) (3.7)
# Requirement already satisfied: soupsieve>1.2 in /opt/anaconda3/lib/python3.12/site-packages (from beautifulsoup4<5.0.0,>=4.12.2->python-jobspy) (2.5)
# Requirement already satisfied: certifi in /opt/anaconda3/lib/python3.12/site-packages (from httpx<1,>=0.23.0->groq) (2024.7.4)
# Requirement already satisfied: httpcore==1.* in /opt/anaconda3/lib/python3.12/site-packages (from httpx<1,>=0.23.0->groq) (1.0.2)
# Requirement already satisfied: h11<0.15,>=0.13 in /opt/anaconda3/lib/python3.12/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->groq) (0.14.0)
# Requirement already satisfied: six<2,>=1.15 in /opt/anaconda3/lib/python3.12/site-packages (from markdownify<0.14.0,>=0.13.1->python-jobspy) (1.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/anaconda3/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.3.0->python-jobspy) (0.6.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /opt/anaconda3/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.3.0->python-jobspy) (2.23.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/lib/python3.12/site-packages (from requests<3.0.0,>=2.31.0->python-jobspy) (2.0.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/lib/python3.12/site-packages (from requests<3.0.0,>=2.31.0->python-jobspy) (2.2.2)
# Using cached python_jobspy-1.1.76-py3-none-any.whl (38 kB)
# Installing collected packages: python-jobspy
#   Attempting uninstall: python-jobspy
#     Found existing installation: python-jobspy 1.1.75
#     Uninstalling python-jobspy-1.1.75:
#       Successfully uninstalled python-jobspy-1.1.75
# Successfully installed python-jobspy-1.1.76
# Note: you may need to restart the kernel to use updated packages.

# %%
import csv
from jobspy import scrape_jobs

jobs1 = scrape_jobs(
    site_name=[ 
        "linkedin", 
        # "indeed", "glassdoor", "google"
                # "zip_recruiter", 
                ],
    search_term="software engineer",
    google_search_term="software engineer jobs in India",
    location="India",
    results_wanted=2000,
    hours_old=24*7*3, # 3 weeks
    country_indeed='India',
    
    # linkedin_fetch_description=True # gets more info such as description, direct job url (slower)
    # proxies=["208.195.175.46:65095", "208.195.175.45:65095", "localhost"],
)
print(f"Found {len(jobs1)} jobs")
print(jobs1.head())
jobs1.to_csv("a1.csv", quoting=csv.QUOTE_NONNUMERIC, escapechar="\\", index=True) # to_excel



jobs2 = scrape_jobs(
   site_name=[ 
        "linkedin", 
        # "indeed", "glassdoor", "google"
                # "zip_recruiter", 
                ],
    search_term="Backend Developer",
    google_search_term="Backend Developer jobs in India",
    location="India",
    results_wanted=2000,
    hours_old=24*7*3, # 3 weeks
    country_indeed='India',
    
    # linkedin_fetch_description=True # gets more info such as description, direct job url (slower)
    # proxies=["208.195.175.46:65095", "208.195.175.45:65095", "localhost"],
)
print(f"Found {len(jobs2)} jobs")
print(jobs2.head())
jobs2.to_csv("b1.csv", quoting=csv.QUOTE_NONNUMERIC, escapechar="\\", index=True) # to_excel


jobs3 = scrape_jobs(
    site_name=[ 
        "linkedin",
        #   "indeed", "glassdoor", "google"
                # "zip_recruiter", 
                ],
    search_term="Full Stack Developer",
    google_search_term="Full Stack Developer jobs in India",
    location="India",
    results_wanted=2000,
    hours_old=24*7*3, # 3 weeks
    country_indeed='India',
    
    # linkedin_fetch_description=True # gets more info such as description, direct job url (slower)
    # proxies=["208.195.175.46:65095", "208.195.175.45:65095", "localhost"],
)
print(f"Found {len(jobs3)} jobs")
print(jobs3.head())
jobs3.to_csv("c1.csv", quoting=csv.QUOTE_NONNUMERIC, escapechar="\\", index=True) # to_excel
# Out:
# 2024-12-05 20:03:37,378 - INFO - JobSpy:LinkedIn - search page: 1 / 200
# 2024-12-05 20:03:45,167 - INFO - JobSpy:LinkedIn - search page: 2 / 200
# 2024-12-05 20:04:16,498 - ERROR - JobSpy:LinkedIn - LinkedIn: HTTPSConnectionPool(host='www.linkedin.com', port=443): Max retries exceeded with url: /jobs-guest/jobs/api/seeMoreJobPostings/search?keywords=software+engineer&location=India&distance=50&pageNum=0&start=10&f_TPR=r1814400 (Caused by ResponseError('too many 429 error responses'))
# 2024-12-05 20:04:16,501 - INFO - JobSpy:Linkedin - finished scraping
# 2024-12-05 20:04:16,549 - INFO - JobSpy:LinkedIn - search page: 1 / 200
# Found 10 jobs
#               id      site                                        job_url  \
# 0  li-4067896580  linkedin  https://www.linkedin.com/jobs/view/4067896580
# 1  li-4067892974  linkedin  https://www.linkedin.com/jobs/view/4067892974
# 2  li-4067893845  linkedin  https://www.linkedin.com/jobs/view/4067893845
# 3  li-4067894655  linkedin  https://www.linkedin.com/jobs/view/4067894655
# 4  li-4067895602  linkedin  https://www.linkedin.com/jobs/view/4067895602
#
#   job_url_direct                                         title company  \
# 0           None  Software Engineer, University Graduate, 2025  Google
# 1           None  Software Engineer, University Graduate, 2025  Google
# 2           None  Software Engineer, University Graduate, 2025  Google
# 3           None  Software Engineer, University Graduate, 2025  Google
# 4           None  Software Engineer, University Graduate, 2025  Google
#
#                       location date_posted job_type salary_source  ... emails  \
# 0   Mumbai, Maharashtra, India  2024-11-29     None          None  ...   None
# 1     Gurugram, Haryana, India  2024-11-29     None          None  ...   None
# 2  Bengaluru, Karnataka, India  2024-11-29     None          None  ...   None
# 3     Pune, Maharashtra, India  2024-11-29     None          None  ...   None
# 4  Hyderabad, Telangana, India  2024-11-29     None          None  ...   None
#
#   description company_industry                              company_url  \
# 0        None             None  https://www.linkedin.com/company/google
# 1        None             None  https://www.linkedin.com/company/google
# 2        None             None  https://www.linkedin.com/company/google
# 3        None             None  https://www.linkedin.com/company/google
# 4        None             None  https://www.linkedin.com/company/google
#
#   company_logo company_url_direct company_addresses company_num_employees  \
# 0         None               None              None                  None
# 1         None               None              None                  None
# 2         None               None              None                  None
# 3         None               None              None                  None
# 4         None               None              None                  None
#
#   company_revenue company_description
# 0            None                None
# 1            None                None
# 2            None                None
# 3            None                None
# 4            None                None
#
# [5 rows x 28 columns]
# 2024-12-05 20:04:34,236 - INFO - JobSpy:LinkedIn - search page: 2 / 200
# 2024-12-05 20:05:05,458 - ERROR - JobSpy:LinkedIn - LinkedIn: HTTPSConnectionPool(host='www.linkedin.com', port=443): Max retries exceeded with url: /jobs-guest/jobs/api/seeMoreJobPostings/search?keywords=Backend+Developer&location=India&distance=50&pageNum=0&start=10&f_TPR=r1814400 (Caused by ResponseError('too many 429 error responses'))
# 2024-12-05 20:05:05,459 - INFO - JobSpy:Linkedin - finished scraping
# 2024-12-05 20:05:05,489 - INFO - JobSpy:LinkedIn - search page: 1 / 200
# Found 10 jobs
#               id      site                                        job_url  \
# 0  li-4086551931  linkedin  https://www.linkedin.com/jobs/view/4086551931
# 1  li-4085110296  linkedin  https://www.linkedin.com/jobs/view/4085110296
# 2  li-4085109487  linkedin  https://www.linkedin.com/jobs/view/4085109487
# 3  li-4085112260  linkedin  https://www.linkedin.com/jobs/view/4085112260
# 4  li-4085109486  linkedin  https://www.linkedin.com/jobs/view/4085109486
#
#   job_url_direct                 title                      company  \
# 0           None  Full Stack Developer  Reliance Industries Limited
# 1           None        Java Developer                     Deloitte
# 2           None        Java Developer                     Deloitte
# 3           None        Java Developer                     Deloitte
# 4           None        Java Developer                     Deloitte
#
#                           location date_posted job_type salary_source  ...  \
# 0  Navi Mumbai, Maharashtra, India  2024-12-02     None          None  ...
# 1      Bengaluru, Karnataka, India  2024-11-28     None          None  ...
# 2                                   2024-11-28     None          None  ...
# 3         Pune, Maharashtra, India  2024-11-28     None          None  ...
# 4      Hyderabad, Telangana, India  2024-11-28     None          None  ...
#
#   emails description company_industry  \
# 0   None        None             None
# 1   None        None             None
# 2   None        None             None
# 3   None        None             None
# 4   None        None             None
#
#                                  company_url company_logo company_url_direct  \
# 0   https://in.linkedin.com/company/reliance         None               None
# 1  https://www.linkedin.com/company/deloitte         None               None
# 2  https://www.linkedin.com/company/deloitte         None               None
# 3  https://www.linkedin.com/company/deloitte         None               None
# 4  https://www.linkedin.com/company/deloitte         None               None
#
#   company_addresses company_num_employees company_revenue company_description
# 0              None                  None            None                None
# 1              None                  None            None                None
# 2              None                  None            None                None
# 3              None                  None            None                None
# 4              None                  None            None                None
#
# [5 rows x 28 columns]
# 2024-12-05 20:05:36,822 - ERROR - JobSpy:LinkedIn - LinkedIn: HTTPSConnectionPool(host='www.linkedin.com', port=443): Max retries exceeded with url: /jobs-guest/jobs/api/seeMoreJobPostings/search?keywords=Full+Stack+Developer&location=India&distance=50&pageNum=0&start=0&f_TPR=r1814400 (Caused by ResponseError('too many 429 error responses'))
# 2024-12-05 20:05:36,823 - INFO - JobSpy:Linkedin - finished scraping
# Found 0 jobs
# Empty DataFrame
# Columns: []
# Index: []

# %%
import pandas as pd
df1 = pd.read_csv("a.csv")
df2 = pd.read_csv("b.csv")
df3 = pd.read_csv("c.csv")
df = pd.concat([df1, df2, df3], axis=0, ignore_index=True)

# Remove duplicate rows
df=df.drop_duplicates()

# Display the cleaned DataFrame
df.head(10)
# Out:
#    Unnamed: 0                id       site  \
# 0           0  gd-1009553983699  glassdoor
# 1           1  gd-1009553631407  glassdoor
# 2           2  gd-1009553616705  glassdoor
# 3           3  gd-1009554071867  glassdoor
# 4           4  gd-1009553922177  glassdoor
# 5           5  gd-1009554014395  glassdoor
# 6           6  gd-1009553671170  glassdoor
# 7           7  gd-1009554071829  glassdoor
# 8           8  gd-1009553117954  glassdoor
# 9           9  gd-1009553923963  glassdoor
#
#                                              job_url job_url_direct  \
# 0  https://www.glassdoor.co.in/job-listing/j?jl=1...            NaN
# 1  https://www.glassdoor.co.in/job-listing/j?jl=1...            NaN
# 2  https://www.glassdoor.co.in/job-listing/j?jl=1...            NaN
# 3  https://www.glassdoor.co.in/job-listing/j?jl=1...            NaN
# 4  https://www.glassdoor.co.in/job-listing/j?jl=1...            NaN
# 5  https://www.glassdoor.co.in/job-listing/j?jl=1...            NaN
# 6  https://www.glassdoor.co.in/job-listing/j?jl=1...            NaN
# 7  https://www.glassdoor.co.in/job-listing/j?jl=1...            NaN
# 8  https://www.glassdoor.co.in/job-listing/j?jl=1...            NaN
# 9  https://www.glassdoor.co.in/job-listing/j?jl=1...            NaN
#
#                                         title  \
# 0                           Software Engineer
# 1                   Trainee Software Engineer
# 2                      Java Software Engineer
# 3                 Associate Software Engineer
# 4                    Software Engineer (Java)
# 5                 Associate Software Engineer
# 6             Software Development Engineer 4
# 7               Application Software Engineer
# 8                Associate Engineer -Software
# 9  Software Engineer II : Automation Engineer
#
#                                company   location date_posted job_type  ...  \
# 0                                Optum  Hyderābād  2024-12-05      NaN  ...
# 1            Peerbits Solution Pvt Ltd      India  2024-12-05      NaN  ...
# 2  Incede Technologies Private Limited    Calicut  2024-12-05      NaN  ...
# 3                 NextBridge Solutions       Pune  2024-12-05      NaN  ...
# 4                           miniOrange      India  2024-12-05      NaN  ...
# 5                               Lowe's  Bengaluru  2024-12-05      NaN  ...
# 6                              Amadeus  Bengaluru  2024-12-05      NaN  ...
# 7                 NextBridge Solutions       Pune  2024-12-05      NaN  ...
# 8                             Raytheon  Bengaluru  2024-12-05      NaN  ...
# 9                        JPMorganChase  Bengaluru  2024-12-05      NaN  ...
#
#   emails                                        description  company_industry  \
# 0    NaN  Optum is a global organization that delivers c...               NaN
# 1    NaN                                                NaN               NaN
# 2    NaN                                                NaN               NaN
# 3    NaN                                                NaN               NaN
# 4    NaN                                                NaN               NaN
# 5    NaN                                                NaN               NaN
# 6    NaN  **Job Title**\n\n\nSoftware Development Engine...               NaN
# 7    NaN  An Inspiring Work Culture \\| Flexible Working...               NaN
# 8    NaN  **Date Posted:**\n\n\n2022\\-04\\-11\\-07:00**...               NaN
# 9    NaN                                                NaN               NaN
#
#                                          company_url  \
# 0  https://www.glassdoor.co.in/Overview/W-EI_IE24...
# 1  https://www.glassdoor.co.in/Overview/W-EI_IE87...
# 2                                                NaN
# 3  https://www.glassdoor.co.in/Overview/W-EI_IE50...
# 4  https://www.glassdoor.co.in/Overview/W-EI_IE71...
# 5  https://www.glassdoor.co.in/Overview/W-EI_IE41...
# 6  https://www.glassdoor.co.in/Overview/W-EI_IE69...
# 7  https://www.glassdoor.co.in/Overview/W-EI_IE50...
# 8  https://www.glassdoor.co.in/Overview/W-EI_IE56...
# 9  https://www.glassdoor.co.in/Overview/W-EI_IE52...
#
#                                         company_logo company_url_direct  \
# 0  https://media.glassdoor.com/sql/2409113/optum-...                NaN
# 1  https://media.glassdoor.com/sql/875763/peerbit...                NaN
# 2                                                NaN                NaN
# 3  https://media.glassdoor.com/sql/5077414/nextbr...                NaN
# 4  https://media.glassdoor.com/sql/711700/miniora...                NaN
# 5  https://media.glassdoor.com/sql/415/lowe-s-hom...                NaN
# 6  https://media.glassdoor.com/sql/6940/amadeus-s...                NaN
# 7  https://media.glassdoor.com/sql/5077414/nextbr...                NaN
# 8  https://media.glassdoor.com/sql/561/rtx-square...                NaN
# 9  https://media.glassdoor.com/sql/5224839/jpmorg...                NaN
#
#    company_addresses  company_num_employees company_revenue  \
# 0                NaN                    NaN             NaN
# 1                NaN                    NaN             NaN
# 2                NaN                    NaN             NaN
# 3                NaN                    NaN             NaN
# 4                NaN                    NaN             NaN
# 5                NaN                    NaN             NaN
# 6                NaN                    NaN             NaN
# 7                NaN                    NaN             NaN
# 8                NaN                    NaN             NaN
# 9                NaN                    NaN             NaN
#
#   company_description
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN
# 5                 NaN
# 6                 NaN
# 7                 NaN
# 8                 NaN
# 9                 NaN
#
# [10 rows x 29 columns]

# %%
df = df[["job_url", "title", "company", "location", "date_posted","description",]]
df.head(10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 df = df[["job_url", "title", "company", "location", "date_posted","description",]]
#       2 df.head(10)
#
# NameError: name 'df' is not defined

# %%
df['id'] = range(1, len(df) + 1)

# %%
df.head(10)
# Out:
#                                              job_url  \
# 0  https://www.glassdoor.co.in/job-listing/j?jl=1...
# 1  https://www.glassdoor.co.in/job-listing/j?jl=1...
# 2  https://www.glassdoor.co.in/job-listing/j?jl=1...
# 3  https://www.glassdoor.co.in/job-listing/j?jl=1...
# 4  https://www.glassdoor.co.in/job-listing/j?jl=1...
# 5  https://www.glassdoor.co.in/job-listing/j?jl=1...
# 6  https://www.glassdoor.co.in/job-listing/j?jl=1...
# 7  https://www.glassdoor.co.in/job-listing/j?jl=1...
# 8  https://www.glassdoor.co.in/job-listing/j?jl=1...
# 9  https://www.glassdoor.co.in/job-listing/j?jl=1...
#
#                                         title  \
# 0                           Software Engineer
# 1                   Trainee Software Engineer
# 2                      Java Software Engineer
# 3                 Associate Software Engineer
# 4                    Software Engineer (Java)
# 5                 Associate Software Engineer
# 6             Software Development Engineer 4
# 7               Application Software Engineer
# 8                Associate Engineer -Software
# 9  Software Engineer II : Automation Engineer
#
#                                company   location date_posted  \
# 0                                Optum  Hyderābād  2024-12-05
# 1            Peerbits Solution Pvt Ltd      India  2024-12-05
# 2  Incede Technologies Private Limited    Calicut  2024-12-05
# 3                 NextBridge Solutions       Pune  2024-12-05
# 4                           miniOrange      India  2024-12-05
# 5                               Lowe's  Bengaluru  2024-12-05
# 6                              Amadeus  Bengaluru  2024-12-05
# 7                 NextBridge Solutions       Pune  2024-12-05
# 8                             Raytheon  Bengaluru  2024-12-05
# 9                        JPMorganChase  Bengaluru  2024-12-05
#
#                                          description  id
# 0  Optum is a global organization that delivers c...   1
# 1                                                NaN   2
# 2                                                NaN   3
# 3                                                NaN   4
# 4                                                NaN   5
# 5                                                NaN   6
# 6  **Job Title**\n\n\nSoftware Development Engine...   7
# 7  An Inspiring Work Culture \\| Flexible Working...   8
# 8  **Date Posted:**\n\n\n2022\\-04\\-11\\-07:00**...   9
# 9                                                NaN  10

# %%
# Filter rows with empty or NaN descriptions
no_description_df = df[df['description'].isna() | (df['description'].str.strip() == "")]

# Remove these rows from the original DataFrame
df = df[~(df['description'].isna() | (df['description'].str.strip() == ""))]

# Add auto-incrementing ID column to both DataFrames
df['id'] = range(1, len(df) + 1)
no_description_df['id'] = range(1, len(no_description_df) + 1)

df.to_csv("jobs_with_description.csv", quoting=csv.QUOTE_NONNUMERIC, escapechar="\\", index=False) # to_excel

no_description_df.to_csv("jobs_without_description.csv", quoting=csv.QUOTE_NONNUMERIC, escapechar="\\", index=False) # to_excel

# %%
import pandas as pd
df= pd.read_csv("jobs_with_description.csv")
df.head(10)
# Out:
#                                              job_url  \
# 0  https://www.glassdoor.co.in/job-listing/j?jl=1...
# 1  https://www.glassdoor.co.in/job-listing/j?jl=1...
# 2  https://www.glassdoor.co.in/job-listing/j?jl=1...
# 3  https://www.glassdoor.co.in/job-listing/j?jl=1...
# 4  https://www.glassdoor.co.in/job-listing/j?jl=1...
# 5  https://www.glassdoor.co.in/job-listing/j?jl=1...
# 6  https://www.glassdoor.co.in/job-listing/j?jl=1...
# 7  https://www.glassdoor.co.in/job-listing/j?jl=1...
# 8  https://www.glassdoor.co.in/job-listing/j?jl=1...
# 9  https://www.glassdoor.co.in/job-listing/j?jl=1...
#
#                                           title  \
# 0                             Software Engineer
# 1               Software Development Engineer 4
# 2                 Application Software Engineer
# 3                  Associate Engineer -Software
# 4                  Software Engineer III - Java
# 5  Executive Assistant/Senior Software Engineer
# 6            Associate Test Automation Engineer
# 7                             Software Engineer
# 8       Software Engineer (Scala, Spark, Azure)
# 9  Cloud Engineer – Enterprise Cloud Experience
#
#                              company   location date_posted  \
# 0                              Optum  Hyderābād  2024-12-05
# 1                            Amadeus  Bengaluru  2024-12-05
# 2               NextBridge Solutions       Pune  2024-12-05
# 3                           Raytheon  Bengaluru  2024-12-05
# 4                      JPMorganChase  Bengaluru  2024-12-05
# 5                               HSBC       Pune  2024-12-05
# 6                             Oracle  Bengaluru  2024-12-05
# 7  UPTODATE PROJECTS PRIVATE LIMITED      Banda  2024-12-05
# 8                                UBS       Pune  2024-12-05
# 9                  ProntoDigital LLC        NaN  2024-12-05
#
#                                          description  id
# 0  Optum is a global organization that delivers c...   1
# 1  **Job Title**\n\n\nSoftware Development Engine...   2
# 2  An Inspiring Work Culture \\\\| Flexible Worki...   3
# 3  **Date Posted:**\n\n\n2022\\\\-04\\\\-11\\\\-0...   4
# 4  **JOB DESCRIPTION**  \n\nWe have an exciting a...   5
# 5  Job description\nSome careers shine brighter t...   6
# 6  Preferred Skillset:\n\n\n* Strong analytical a...   7
# 7  Software Engineer responsibilities include:\n\...   8
# 8  India\nInformation Technology (IT)\nGroup Func...   9
# 9  **Location:** Remote  \n**Employment Type:** F...  10

# %%
import re
import pandas as pd

output_csv = "filter1.csv"

# Function to extract sentences with keywords and surrounding context
def extract_with_context(text, keywords, word_count=20):
    if pd.isna(text):
        return "Not specified"  # Return default value for NaN values

    # Regular expression to find keywords with surrounding context
    pattern = rf"((?:\S+\s){{0,{word_count}}}?\b(?:{'|'.join(keywords)})\b(?:\s\S+){{0,{word_count}}})"
    
    match = re.search(pattern, text, re.IGNORECASE)
    if match:
        return match.group(1).strip()  # Extract the match and return it
    return "Not specified"  # Default value if no match is found

# Define keywords
keywords = ["year", "experience", "fresher", "Experience Level"]

# Apply the function to the job description column
df['experience_required_filter1'] = df['description'].apply(lambda x: extract_with_context(x, keywords))

# Save the updated DataFrame to a new CSV file
df.to_csv(output_csv, index=False)

print(f"Updated file saved as {output_csv}")
# Out:
# Updated file saved as filter1.csv

# %%
df.head(10)
# Out:
#                                              job_url  \
# 0  https://www.glassdoor.co.in/job-listing/j?jl=1...
# 1  https://www.glassdoor.co.in/job-listing/j?jl=1...
# 2  https://www.glassdoor.co.in/job-listing/j?jl=1...
# 3  https://www.glassdoor.co.in/job-listing/j?jl=1...
# 4  https://www.glassdoor.co.in/job-listing/j?jl=1...
# 5  https://www.glassdoor.co.in/job-listing/j?jl=1...
# 6  https://www.glassdoor.co.in/job-listing/j?jl=1...
# 7  https://www.glassdoor.co.in/job-listing/j?jl=1...
# 8  https://www.glassdoor.co.in/job-listing/j?jl=1...
# 9  https://www.glassdoor.co.in/job-listing/j?jl=1...
#
#                                           title  \
# 0                             Software Engineer
# 1               Software Development Engineer 4
# 2                 Application Software Engineer
# 3                  Associate Engineer -Software
# 4                  Software Engineer III - Java
# 5  Executive Assistant/Senior Software Engineer
# 6            Associate Test Automation Engineer
# 7                             Software Engineer
# 8       Software Engineer (Scala, Spark, Azure)
# 9  Cloud Engineer – Enterprise Cloud Experience
#
#                              company   location date_posted  \
# 0                              Optum  Hyderābād  2024-12-05
# 1                            Amadeus  Bengaluru  2024-12-05
# 2               NextBridge Solutions       Pune  2024-12-05
# 3                           Raytheon  Bengaluru  2024-12-05
# 4                      JPMorganChase  Bengaluru  2024-12-05
# 5                               HSBC       Pune  2024-12-05
# 6                             Oracle  Bengaluru  2024-12-05
# 7  UPTODATE PROJECTS PRIVATE LIMITED      Banda  2024-12-05
# 8                                UBS       Pune  2024-12-05
# 9                  ProntoDigital LLC        NaN  2024-12-05
#
#                                          description  id  \
# 0  Optum is a global organization that delivers c...   1
# 1  **Job Title**\n\n\nSoftware Development Engine...   2
# 2  An Inspiring Work Culture \\\\| Flexible Worki...   3
# 3  **Date Posted:**\n\n\n2022\\\\-04\\\\-11\\\\-0...   4
# 4  **JOB DESCRIPTION**  \n\nWe have an exciting a...   5
# 5  Job description\nSome careers shine brighter t...   6
# 6  Preferred Skillset:\n\n\n* Strong analytical a...   7
# 7  Software Engineer responsibilities include:\n\...   8
# 8  India\nInformation Technology (IT)\nGroup Func...   9
# 9  **Location:** Remote  \n**Employment Type:** F...  10
#
#                          experience_required_filter1
# 0  * BE/B.Tech or equivalent degree\n* 4\\\\+ yea...
# 1  * Has working experience and advanced and spec...
# 2  * Full Stack Developer with Dot Net, Java, JSP...
# 3                                      Not specified
# 4  * Formal training or certification on software...
# 5  be successful in this role, you should meet th...
# 6                                      Not specified
# 7  * Proven work experience as a Software Enginee...
# 8  and strengthen our position as digital pioneer...
# 9  proficiency in designing, implementing, and ma...

# %%
import os
import pandas as pd
from groq import Groq
from dotenv import load_dotenv
import time

# Load environment variables
load_dotenv()

# Groq initialization
groq_api_key = os.getenv("GROQ_API_KEY")
model_name = os.getenv("MODEL_NAME")
client = Groq(api_key=groq_api_key)

def extract_experience(client, model_name, description):
    if not description:
        return "No description provided"  # Return a default value for no text

    # Construct the prompt
    prompt = f"""
    Extract the years of experience required from the following job details. If experience is not mentioned explicitly, return 0.

    ### Examples:
    1. "Exp - 5+ Years" → 5
    2. "Must have 7 years of hands-on developer experience." → 7
    3. "6-8 years of relevant experience in software development in skills listed below." → 6 (use the minimum value if a range is given)
    4. "At least five years of experience in a managerial role." → 5
    5. "Experience: None required." → 0
    6. "Proven Experience" → 1
    

    ### Job Text:
    {description}
    """

    messages = [
        {"role": "system", "content": "You are a helpful assistant specializing in extracting years of experience from job details."},
        {"role": "user", "content": prompt},
    ]
    try:
        # Make the request to the Groq API
        response = client.chat.completions.create(
            model=model_name,
            messages=messages,
            temperature=0.5,
            max_tokens=100
        )
        
        # Extract the LLM response
        llm_response = response.choices[0].message.content.strip()
        return llm_response

    except Exception as e:
        print(f"Error processing text:\n{description}\nError: {e}")
        return str(e)  # Return the error message


# Read the CSV file
input_csv = "filter1.csv"
output_csv = "final_result_with_llm_response.csv"

df = pd.read_csv(input_csv)

# Ensure 'description' column exists
if "description" not in df.columns:
    raise ValueError("The input CSV does not have a 'description' column.")

# Add a new column for LLM response
df["llm_response"] = ""

# Process each row
for index, row in df.iterrows():
    description = row["description"]
    id = row.get("id", index)  # Use 'id' if available, otherwise fallback to index
    print(f"Processing ID: {id}")


    start_time = time.time()
    llm_response = extract_experience(client, model_name, description)
    df.at[index, "llm_response"] = llm_response 
    end_time = time.time() 
    time_taken = end_time - start_time
    print(f"Time taken for ID {id}: {time_taken} seconds")


    # Pause to respect API rate limits
    time.sleep(1)  

# Save the updated DataFrame to a new CSV file
df.to_csv(output_csv, index=False)

print(f"Processing complete. Updated file saved as {output_csv}")
# Out:
# Processing ID: 1
# Time taken for ID 1: 0.7272720336914062 seconds
# Processing ID: 2
# Time taken for ID 2: 0.8233389854431152 seconds
# Processing ID: 3
# Time taken for ID 3: 0.5411219596862793 seconds
# Processing ID: 4
# Time taken for ID 4: 0.37003016471862793 seconds
# Processing ID: 5
# Time taken for ID 5: 0.5825562477111816 seconds
# Processing ID: 6
# Time taken for ID 6: 0.7229921817779541 seconds
# Processing ID: 7
# Time taken for ID 7: 0.46062803268432617 seconds
# Processing ID: 8
# Time taken for ID 8: 0.7709469795227051 seconds
# Processing ID: 9
